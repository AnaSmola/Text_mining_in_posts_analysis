# %%
import pandas as pd
import string
from pandas import DataFrame
from pandas import Series
import re
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r'C:\Users\dell\Desktop\pliki\translated_comments.csv')
df.head()
# Out:
#                                              comment  likes  my_polarity  \
# 0  В Польшу уехали не от хорошей жизни.Я сам убеж...    7.0         -1.0
# 1  Здравствуйте, Светлана! Честно говоря, мы до л...    3.0          1.0
# 2  люди разные в разных странах, и не зависит от ...    3.0         -1.0
# 3                           Светлана, ты молодец 👍💪💪    1.0          1.0
# 4  Приветствую. Автор высказался субъективно. Я м...    8.0          0.0
#
#                                          eng_comment
# 0  They did not leave Poland from a good life. I ...
# 1  Hello Svetlana! Honestly, we ourselves did not...
# 2  People are different in different countries, a...
# 3                         Svetlana, you're well done
# 4  Greetings. The author spoke subjectively. For ...

# %%
df
# Out:
#                                               comment  likes  my_polarity  \
# 0   В Польшу уехали не от хорошей жизни.Я сам убеж...    7.0         -1.0
# 1   Здравствуйте, Светлана! Честно говоря, мы до л...    3.0          1.0
# 2   люди разные в разных странах, и не зависит от ...    3.0         -1.0
# 3                            Светлана, ты молодец 👍💪💪    1.0          1.0
# 4   Приветствую. Автор высказался субъективно. Я м...    8.0          0.0
# ..                                                ...    ...          ...
# 81  спасибо вам за написанное! Спасибо что прочита...    1.0          1.0
# 82  да мне бы знающего человека и разбирающегося в...    0.0          1.0
# 83  Ну, так перечитайте внимательно ЧТО ИМЕННО Вы ...    3.0          0.0
# 84  я видела их посты,я читала о чем пишут люди! В...    9.0          1.0
# 85  не бери близко к сердцу... Люди разные.. Подсо...    1.0          0.0
#
#                                           eng_comment
# ...

# %%
del df["my_polarity"]

# %%
df
# Out:
#                                               comment  likes  \
# 0   В Польшу уехали не от хорошей жизни.Я сам убеж...    7.0
# 1   Здравствуйте, Светлана! Честно говоря, мы до л...    3.0
# 2   люди разные в разных странах, и не зависит от ...    3.0
# 3                            Светлана, ты молодец 👍💪💪    1.0
# 4   Приветствую. Автор высказался субъективно. Я м...    8.0
# ..                                                ...    ...
# 81  спасибо вам за написанное! Спасибо что прочита...    1.0
# 82  да мне бы знающего человека и разбирающегося в...    0.0
# 83  Ну, так перечитайте внимательно ЧТО ИМЕННО Вы ...    3.0
# 84  я видела их посты,я читала о чем пишут люди! В...    9.0
# 85  не бери близко к сердцу... Люди разные.. Подсо...    1.0
#
#                                           eng_comment
# 0   They did not leave Poland from a good life. I ...
# 1   Hello Svetlana! Honestly, we ourselves did not...
# 2   People are different in different countries, a...
# ...

# %%
# Sentiment Scoring
from textblob import TextBlob

# %%
df["blob_polarity"] = df ["eng_comment"].apply(lambda x: TextBlob(x).sentiment[0])

# %%
df.head(20)
# Out:
#                                               comment  likes  \
# 0   В Польшу уехали не от хорошей жизни.Я сам убеж...    7.0
# 1   Здравствуйте, Светлана! Честно говоря, мы до л...    3.0
# 2   люди разные в разных странах, и не зависит от ...    3.0
# 3                            Светлана, ты молодец 👍💪💪    1.0
# 4   Приветствую. Автор высказался субъективно. Я м...    8.0
# 5   Не надо о украинцах плохо думать. Прекрасный н...   31.0
# 6   Вы запутались, женщина)) Среди жителей украины...    0.0
# 7   Спасибо за такие слова. Среди наших тоже есть ...    0.0
# 8   Я восхищаюсь смелостью украинцев - как вы пове...   10.0
# 9   Не могу не сказать о украинцах..\nВсе,кто был ...   20.0
# 10  Как интересно наблюдать с точки зрения психоло...   19.0
# 11  Гнильца осталась дома. Лучшие уехали((( Хотя в...    4.0
# 12  Смотрите,друзья! Я написала свои мысли,свои эм...    7.0
# 13  Если бы Белорусы были такие сплочённый, как вы...    6.0
# ...

# %%
df.iloc[76]
# Out:
# comment          вот этот пессимистичный текст точно не поспосо...
# likes                                                          3.0
# eng_comment      This pessimistic text will definitely not cont...
# blob_polarity                                             0.045313
# Name: 76, dtype: object

# %%
df.loc[df['blob_polarity'] == 0.000000]
# Out:
#                                               comment  likes  \
# 3                            Светлана, ты молодец 👍💪💪    1.0
# 7   Спасибо за такие слова. Среди наших тоже есть ...    0.0
# 17  Каждый судит по себе...не думаю что вы имеете ...    8.0
# 25  Пост разжигающий вражду. Зачем сравнивать разн...   24.0
# 27  Слезьте с украинцев много чего было в 2014 Вы ...    6.0
# 33                      Спасибо вам за вашу поддержку    3.0
# 35  Так вот и беларусам сейчас помогают не просто ...    0.0
# 38                             а причём тут 2014 год?   14.0
# 41                           Держитесь! Молюсь о Вас!    0.0
# 49  это вы уже преувеличиваете... Доброты и тепла,...    1.0
# 63  да я знаю про помощь, сама такая, до сих пор о...    3.0
# 67  может быть и так((( Не могу судить и не могу г...    0.0
# 79  я вам запрос отправила и написала в месенджер,...    0.0
# 80  Сплочённые, но доверчивые. Этим пользуются наш...    0.0
# ...

# %%
# Find and compare the polarity 0.0 from TextBlob 
text_blob_ru = TextBlob("Сплочённые, но доверчивые. Этим пользуются наши враги.")

# %%
text_blob_en = text_blob_ru.translate(from_lang = 'ru', to = 'en')

# %%
print(text_blob_en, '->', text_blob_en. sentiment)
# Out:
# Coated, but gullible. Our enemies use this. -> Sentiment(polarity=0.0, subjectivity=0.0)

# %%
text_blob_ru = TextBlob("Каждый судит по себе...не думаю что вы имеете к Украине и украинцам какое либо отношение. Напоминает мне Лукашенка с его 'народец'")

# %%
text_blob_en = text_blob_ru.translate(from_lang = 'ru', to = 'en')

# %%
print(text_blob_en, '->', text_blob_en. sentiment)
# Out:
# Everyone judges by himself ... I do not think that you have any attitude towards Ukraine and Ukrainians. Reminds me of Lukashenka with his 'people' -> Sentiment(polarity=0.0, subjectivity=0.0)

# %%
text_blob_ru2 = TextBlob("Спасибо за ваш комментарий! 🤗Есть и хорошие и плохие люди,как кто-то написал,не в зависимости от нации.... Писала на эмоциях и о том,что меня больше задело,что больше увидела! Но,есть человеческий фактор,который ни кто не отменял....и в украинском народе есть хорошие люди,кто помогает безвозмездно и т д......Пост был обо всем,и о людях и об отношении и о помощи! Опять же,кто,что увидел,кому,что ближе...")

# %%
text_blob_en2 = text_blob_ru2.translate(from_lang = 'ru', to = 'en')

# %%
print(text_blob_en2, '->', text_blob_en2. sentiment)
# Out:
# Thank you for your comment! 🤗n, both good and bad people, as someone wrote, is not depending on the nation .... wrote on emotions and that I was more hit, what I saw more! But, there is a human factor that no one canceled .... And in the Ukrainian people there are good people who help free of charge, etc. ...... The post was about everything, about people and about attitude and help! Again, who saw what, to whom, what is closer ... -> Sentiment(polarity=0.3321428571428572, subjectivity=0.5380952380952381)

# %%
# Add the column for summarising the polarity
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
df['blob_pred'] = df['blob_polarity'].apply(lambda x: getAnalysis(x))

# %%
#df["Polarity"] = df ["Eng_Sentence"].apply(lambda x: TextBlob(x).sentiment[0])

# %%
df
# Out:
#                                               comment  likes  \
# 0   В Польшу уехали не от хорошей жизни.Я сам убеж...    7.0
# 1   Здравствуйте, Светлана! Честно говоря, мы до л...    3.0
# 2   люди разные в разных странах, и не зависит от ...    3.0
# 3                            Светлана, ты молодец 👍💪💪    1.0
# 4   Приветствую. Автор высказался субъективно. Я м...    8.0
# ..                                                ...    ...
# 81  спасибо вам за написанное! Спасибо что прочита...    1.0
# 82  да мне бы знающего человека и разбирающегося в...    0.0
# 83  Ну, так перечитайте внимательно ЧТО ИМЕННО Вы ...    3.0
# 84  я видела их посты,я читала о чем пишут люди! В...    9.0
# 85  не бери близко к сердцу... Люди разные.. Подсо...    1.0
#
#                                           eng_comment  blob_polarity blob_pred
# 0   They did not leave Poland from a good life. I ...       0.232143  Positive
# ...

# %%
#df['my_polarity'] = df['my_polarity'].astype(int)

# %%
# Add the column for summarising the polarity
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
#df['my_polarity_pred'] = df['my_polarity'].apply(lambda x: getAnalysis(x))

# %%
df
# Out:
#                                               comment  likes  \
# 0   В Польшу уехали не от хорошей жизни.Я сам убеж...    7.0
# 1   Здравствуйте, Светлана! Честно говоря, мы до л...    3.0
# 2   люди разные в разных странах, и не зависит от ...    3.0
# 3                            Светлана, ты молодец 👍💪💪    1.0
# 4   Приветствую. Автор высказался субъективно. Я м...    8.0
# ..                                                ...    ...
# 81  спасибо вам за написанное! Спасибо что прочита...    1.0
# 82  да мне бы знающего человека и разбирающегося в...    0.0
# 83  Ну, так перечитайте внимательно ЧТО ИМЕННО Вы ...    3.0
# 84  я видела их посты,я читала о чем пишут люди! В...    9.0
# 85  не бери близко к сердцу... Люди разные.. Подсо...    1.0
#
#                                           eng_comment  blob_polarity blob_pred
# 0   They did not leave Poland from a good life. I ...       0.232143  Positive
# ...

# %%
df[df.blob_polarity > 0.48]
# Out:
#                                               comment  likes  \
# 21         Что ты несёшь, украинцы - прекрасный народ    0.0
# 30               Отлично. А политику Вы где увидели?)    0.0
# 59  да пожалуйста,делайте заказы или напишите,кто ...    0.0
# 60  действительно, в любой нации есть как хорошие ...    1.0
# 71  я много чего вижу!!!!! Но смысл? Если человек ...    1.0
#
#                                           eng_comment  blob_polarity blob_pred
# 21  What are you carrying, Ukrainians are a wonder...       1.000000  Positive
# 30            Excellent. Where did you see politics?)       1.000000  Positive
# 59  Yes, please make orders or write who cannot af...       0.500000  Positive
# 60  Indeed, in any nation there are both good and ...       0.533333  Positive
# 71  I see a lot of things !!!!! But the meaning? I...       0.485714  Positive

# %%
df[df.blob_polarity < -0.20]
# Out:
#                                               comment  likes  \
# 16  ЭТОТ ПОСТ НАПИСАН НЕ О НАЦИОНАЛИЗМЕ\n НЕ ПРОТИ...   15.0
# 22  А слабо похвалить один народ, не опуская при э...   11.0
# 32  Михаил Невар сложно не реагировать вообще... С...    1.0
# 72  и да, среди тех, кто остался, тоже есть герои,...    2.0
# 78  ну и что? Все это видели, но всё равно шли. По...    1.0
#
#                                           eng_comment  blob_polarity blob_pred
# 16  This post is not written about nationalism\n N...      -0.700000  Negative
# 22  And weakly praise one people, without lowering...      -0.250000  Negative
# 32  Mikhail Nevar is difficult not to react at all...      -0.250000  Negative
# 72  And yes, among those who remained, there are a...      -0.625000  Negative
# 78  so what? They all saw this, but still went. Be...      -0.333333  Negative

# %%
#df.my_polarity = df.my_polarity.astype('string')

# %%
#df['my_polarity'] = df['my_polarity'].astype(str)

# %%
#df['my_polarity'] = df['my_polarity'].str.replace('0', 'neu',regex=True)
#df['my_polarity_pred'] = df['my_polarity'].apply(lambda x: x.replace("1", "pos"))

# %%
#df['my_polarity_pred'] = df['my_polarity'].str.replace('0', 'neu',regex=True)
#df['my_polarity_pred'] = df['my_polarity'].str.replace('1', 'pos',regex=True)
#df['my_polarity_pred'] = df['my_polarity'].str.replace('-1', 'neg',regex=True)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df['blob_pred'].value_counts()

ax = sns.histplot(df["blob_pred"], color = 'green')
#ax.set_style('darkgrid')
ax.set_xlabel("Value")
ax.set_ylabel("posts_count")

ax.set_xticklabels(['Neutral', 'Negative', 'Positive'])
ax.set_title("Sentiment of 'comments' by TextBlob")
# Out:
# C:\Users\dell\AppData\Local\Temp/ipykernel_16272/3311563965.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['Neutral', 'Negative', 'Positive'])
# Text(0.5, 1.0, "Sentiment of 'comments' by TextBlob")

# %%
df[df.blob_pred == 'Negative']
# Out:
#                                               comment  likes  \
# 13  Если бы Белорусы были такие сплочённый, как вы...    6.0
# 16  ЭТОТ ПОСТ НАПИСАН НЕ О НАЦИОНАЛИЗМЕ\n НЕ ПРОТИ...   15.0
# 19  Как говорится , в семье не без урода, везде хв...    5.0
# 22  А слабо похвалить один народ, не опуская при э...   11.0
# 24  Нет плохих национальностей - есть плохие люди…...    6.0
# 28  Это только здесь. В Беларуси друг друга ненави...   24.0
# 32  Михаил Невар сложно не реагировать вообще... С...    1.0
# 34  как же Вас тянет всех к Майдану то))в 2014 нач...    0.0
# 37  да любопытно конечно, как можно 2014 год подве...    0.0
# 40  это не правда! Наш двор, как был сплоченным, т...   10.0
# 44        ого, прям ненавидят друг друга?) уверены?))    3.0
# 45  Живу в Минске. Нормальные обычные люди. Сволоч...    2.0
# 53  наверное мне слабо...... Исходя из всего,что б...    1.0
# 62  ,приезжайте в гости,все будет! 🤗\n Про посты,п...    1.0
# ...

# %%
df[df.blob_pred == 'Positive']
# Out:
#                                               comment  likes  \
# 0   В Польшу уехали не от хорошей жизни.Я сам убеж...    7.0
# 1   Здравствуйте, Светлана! Честно говоря, мы до л...    3.0
# 2   люди разные в разных странах, и не зависит от ...    3.0
# 4   Приветствую. Автор высказался субъективно. Я м...    8.0
# 5   Не надо о украинцах плохо думать. Прекрасный н...   31.0
# 6   Вы запутались, женщина)) Среди жителей украины...    0.0
# 8   Я восхищаюсь смелостью украинцев - как вы пове...   10.0
# 9   Не могу не сказать о украинцах..\nВсе,кто был ...   20.0
# 10  Как интересно наблюдать с точки зрения психоло...   19.0
# 11  Гнильца осталась дома. Лучшие уехали((( Хотя в...    4.0
# 12  Смотрите,друзья! Я написала свои мысли,свои эм...    7.0
# 14  Спасибо Вам за Ваше мнение! И за отношение к б...    5.0
# 15  @Svitlana Milewska а что вас так напугало, что...    6.0
# 18                                          Благодарю    2.0
# ...

# %%
df[df.blob_polarity < -0.2]
# Out:
#                                               comment  likes  \
# 16  ЭТОТ ПОСТ НАПИСАН НЕ О НАЦИОНАЛИЗМЕ\n НЕ ПРОТИ...   15.0
# 22  А слабо похвалить один народ, не опуская при э...   11.0
# 32  Михаил Невар сложно не реагировать вообще... С...    1.0
# 72  и да, среди тех, кто остался, тоже есть герои,...    2.0
# 78  ну и что? Все это видели, но всё равно шли. По...    1.0
#
#                                           eng_comment  blob_polarity blob_pred
# 16  This post is not written about nationalism\n N...      -0.700000  Negative
# 22  And weakly praise one people, without lowering...      -0.250000  Negative
# 32  Mikhail Nevar is difficult not to react at all...      -0.250000  Negative
# 72  And yes, among those who remained, there are a...      -0.625000  Negative
# 78  so what? They all saw this, but still went. Be...      -0.333333  Negative

# %%
df[df.blob_polarity > 0.5]
# Out:
#                                               comment  likes  \
# 21         Что ты несёшь, украинцы - прекрасный народ    0.0
# 30               Отлично. А политику Вы где увидели?)    0.0
# 60  действительно, в любой нации есть как хорошие ...    1.0
#
#                                           eng_comment  blob_polarity blob_pred
# 21  What are you carrying, Ukrainians are a wonder...       1.000000  Positive
# 30            Excellent. Where did you see politics?)       1.000000  Positive
# 60  Indeed, in any nation there are both good and ...       0.533333  Positive

# %%
labeled_TextBlob= df

# %%
labeled_TextBlob.to_csv('C:/Users/dell/Desktop/pliki/labeled_TextBlob.csv', encoding = 'utf-8',  index = False)

# %%
df = pd.read_csv(r'C:\Users\dell\Desktop\pliki\labeled_TextBlob.csv')

# %%
# Find and compare the polarity 0.0 from TextBlob

# %%
text_blob_ru = TextBlob("Связь в этом районе очень плохая")

# %%
text_blob_en = text_blob_ru.translate(from_lang = 'ru', to = 'en')

# %%
print(text_blob_en, '->', text_blob_en. sentiment)
# Out:
# Communication in this area is very bad -> Sentiment(polarity=-0.9099999999999998, subjectivity=0.8666666666666667)

# %%
# Find and compare the polarity 0.0 from TextBlob

# %%
text_blob_ru1 = TextBlob("Завтраки в этом отеле выше всяких похвал")

# %%
text_blob_en1 = text_blob_ru1.translate(from_lang = 'ru', to = 'en')

# %%
print(text_blob_en1, '->', text_blob_en1. sentiment)
# Out:
# Breakfast in this hotel is beyond praise -> Sentiment(polarity=0.0, subjectivity=0.0)
